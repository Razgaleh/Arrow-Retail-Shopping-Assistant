# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("./shared/data/products.csv")
df.head()
# Out:
#       category subcategory                                      name  \
# 0  accessories         bag        Classic Black Patent Leather Purse
# 1  accessories         bag  Embroidered Cream Purse with Gold Detail
# 2  accessories         bag                 Ratan Basket Shoulder Bag
# 3  accessories         bag        Embroidered Leather Bohemian Purse
# 4      apparel       dress             Black Polka-Dotted Slip Dress
#
#                                          description  \
# 0  Introducing the Classic Black Patent Bag, a bl...
# 1  Introducing the Embroidered Cream purse with g...
# 2  The Ratan Basket Shoulder Bag is a charming bl...
# 3  Introducing the Embroidered Fabric Purse, a de...
# 4  Discover timeless elegance with our Black Polk...
#
#                                                  url  price  \
# 0  /images/Classic_Black_Patent_Leather_Purse1-sm...   49.9
# 1              /images/Creme_clutch_purse1-small.jpg   69.9
# ...

# %%
df = pd.read_csv("./shared/data/Product_Dataset_wImages.csv", encoding="latin1")
df['image'] = "/cdw_images/" + df['ProductName'].str.replace(" ", "_") + ".jpg"
clean_df = df.copy()
clean_df['name'] = clean_df['ProductName'].str.title()
clean_df['url'] = clean_df['image']
clean_df['image'] = clean_df['image']
clean_df['category'] = clean_df['LogisticsTaxonomyClassName']
clean_df['subcategory'] = clean_df['LogisticsTaxonomyGroupName']
clean_df['description'] = clean_df['MarketingText']
clean_df = clean_df[['category', 'subcategory', 'name', 'description','url', 'image']]
clean_df
# Out:
#                           category      subcategory  \
# 0                Keyboards/Keypads  Numeric Keypads
# 1                Keyboards/Keypads  Numeric Keypads
# 2                Keyboards/Keypads  Numeric Keypads
# 3                Keyboards/Keypads  Numeric Keypads
# 4                Keyboards/Keypads  Numeric Keypads
# ...                            ...              ...
# 5995  Small & Consumer Electronics            Tools
# 5996  Small & Consumer Electronics            Tools
# 5997  Small & Consumer Electronics            Tools
# 5998  Small & Consumer Electronics            Tools
# 5999  Small & Consumer Electronics            Tools
#
#                                     name  \
# 0        Genovation Lcd Mini Term 12 Usb
# 1        Genovation Lcd Mini Term 12 Usb
# 2        Genovation Lcd Mini Term 12 Usb
# 3        Genovation Lcd Mini Term 12 Usb
# 4        Genovation Lcd Mini Term 12 Usb
# ...                                  ...
# 5995  Fluke Eversharp 66/110 Blade Punch
# ...

# %%
unique_df = clean_df.drop_duplicates()
unique_df['price'] = np.round(np.random.uniform(30, 100, size=len(unique_df)), 2)
unique_df = unique_df.reset_index(drop=True)
unique_df = unique_df[['category', 'subcategory', 'name', 'description','url','price', 'image']]
unique_df.to_csv("./shared/data/clean_cdw_products.csv", index=False)
# Out:
# /tmp/ipykernel_558059/2675632932.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   unique_df['price'] = np.round(np.random.uniform(30, 100, size=len(unique_df)), 2)
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# Cell In[4], line 5
#       3 unique_df = unique_df.reset_index(drop=True)
#       4 unique_df = unique_df[['category', 'subcategory', 'name', 'description','url','price', 'image']]
# ----> 5 unique_df.to_csv("/shared/data/clean_cdw_products.csv", index=False)
#
# ...
